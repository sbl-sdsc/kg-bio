# %% [markdown]
# # Import Pathway data in BioPAX 3 format to Node and Relationship files for Knowledge Graph Import
#
# [BioPAX – Biological Pathways Exchange
# Language
# Level 3](
# http://www.biopax.org/release/biopax-level3-documentation.pdf)
#
# [PyBioPax documentation](https://pybiopax.readthedocs.io/en/latest/)
# [pybiopax repo](https://github.com/indralab/pybiopax)
#
# Author: Peter W. Rose (pwrose@ucsd.edu)

# %%
import os
import pandas as pd
import pybiopax

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns
pd.set_option('display.max_colwidth', None) # don't truncate cells

# %%
def get_id(obj, database, prefix):
    """Return id of Reactome object"""
    if obj:
        for xref in obj.xref:
            if xref.db == database:
                if ':' in xref.id:
                    # remove CURIE
                    return prefix + xref.id.split(':')[1]
                else:
                    return prefix + xref.id
                
    return ''

# %%
def get_version(obj):
    """Return version of Reactome object"""
    for xref in obj.xref:
        if xref.db.startswith('Reactome Database ID Release'):
            return xref.db.split(' ')[4]

    return ''

# %%
def get_component_entity_id(component):
    """Return entity id and database name of a component"""
    entity_type = component.__class__.__name__
    entity_id = ''  
    
    if entity_type == 'Complex':
        entity_id = get_id(component, 'Reactome', 'reactome:')
    elif entity_type == 'Protein':
        entity_id = get_id(component.entity_reference, 'UniProt', 'uniprot:')
    elif entity_type  == 'SmallMolecule':
        entity_id = get_id(component.entity_reference, 'ChEBI', 'chebi:')
            
    return entity_id

# %%
def create_synonym_string(synonyms):
    if isinstance(synonyms, list):
        synonyms = '|'.join(synonyms)
    
    return synonyms

# %%
def extract_pathways(model, node_data, rel_data):
    relationships = {'Pathway': 'IS_A', 'BiochemicalReaction': 'PART_OF'}
        
    for pathway in model.get_objects_by_type(pybiopax.biopax.Pathway):
        row_n = {'entity': 'Pathway', 
                 'id': get_id(pathway, 'Reactome', 'reactome:'), 
                 'reactome_id': get_id(pathway, 'Reactome', ''),
                 'name': pathway.display_name, 
                 'synonyms': create_synonym_string(pathway.name),
                 'version': get_version(pathway)}
        node_data.append(row_n)
    
        for component in pathway.pathway_component:
            entity_type = component.__class__.__name__
            rel = relationships.get(entity_type, '')
            
            if rel != '':
                row_r = {'entity': component.__class__.__name__, 
                         'id': get_id(component, 'Reactome', 'reactome:'),
                         'reactome_id': get_id(component, 'Reactome', ''),
                         'parent_entity': 'Pathway',
                         'parent_id': row_n.get('id'), 
                         'version': get_version(component),
                         'relationship': rel}
                rel_data.append(row_r)
                
    return node_data, rel_data

# %%
def extract_reaction(model, node_data, rel_data):
    for reaction in model.get_objects_by_type(pybiopax.biopax.BiochemicalReaction):
        row_n = {'entity': 'Reaction', 
                 'id': get_id(reaction, 'Reactome', 'reactome:'), 
                 'reactome_id': get_id(reaction, 'Reactome', ''),
                 'name': reaction.display_name, 
                 'synonyms': create_synonym_string(reaction.name),
                 'version': get_version(reaction)}
        node_data.append(row_n)
        
        for reaction_entity in [reaction.left, reaction.right]:
#             if reaction_entity == reaction.left:
#                 relationship = 'CONSUMED_BY'
#             else:
#                 relationship = 'PRODUCED_BY'
                
            # simplified version: only one relationship
            relationship = 'PARTICIPATES_IN'
            
            for component in reaction_entity:
                entity_id = get_component_entity_id(component)

                if entity_id != '':
                    row_r = {'entity': component.__class__.__name__, 
                             'id': entity_id,
                             'reactome_id': get_id(component, 'Reactome', ''),
                             'parent_entity': 'BiochemicalReaction',
                             'parent_id': row_n.get('id'), 
                             'version': get_version(component),
                             'relationship': relationship}
                    rel_data.append(row_r)
                
        
    return node_data, rel_data

# %%
def extract_complexes(model, node_data, rel_data):    
    for cmplx in model.get_objects_by_type(pybiopax.biopax.Complex):
        row_n = {'entity': 'Complex', 
                 'id': get_id(cmplx, 'Reactome', 'reactome:'), 
                 'reactome_id': get_id(cmplx, 'Reactome', ''),
                 'name': cmplx.display_name, 
                 'synonyms': create_synonym_string(cmplx.name),
                 'version': get_version(cmplx)}
        node_data.append(row_n)
    
        for component in cmplx.component:         
            entity_id = get_component_entity_id(component)

            if entity_id != '':
                row_r = {'entity': component.__class__.__name__, 
                         'id': entity_id,
                         'reactome_id': get_id(component, 'Reactome', ''),
                         'parent_entity': 'Complex',
                         'parent_id': row_n.get('id'), 
                         'version': get_version(component),
                         'relationship': 'PART_OF'}
                rel_data.append(row_r)
                
    return node_data, rel_data

# %%
def extract_proteins(model, node_data):
    for protein in model.get_objects_by_type(pybiopax.biopax.Protein):
        row_n = {'entity': 'Protein', 
                 'id': get_id(protein.entity_reference, 'UniProt', 'uniprot:'), 
                 'reactome_id': get_id(protein, 'Reactome', ''),
                 'name': protein.display_name, 
                 'synonyms': create_synonym_string(protein.name),
                 'version': get_version(protein)}
        node_data.append(row_n)
      
    return node_data

# %%
def extract_small_molecules(model, node_data):
    for molecule in model.get_objects_by_type(pybiopax.biopax.SmallMolecule):     
        row_n = {'entity': 'SmallMolecule', 
                 'id': get_id(molecule.entity_reference, 'ChEBI', 'chebi:'), 
                 'reactome_id': get_id(molecule, 'Reactome', ''),
                 'name': molecule.display_name, 
                 'synonyms': create_synonym_string(molecule.name),
                 'version': get_version(molecule)}
        node_data.append(row_n)
      
    return node_data

# %% [markdown]
# ## Extract node and relationship data

# %%
node_data = []
rel_data = []

pathways = ['R-HSA-162582', 'R-HSA-5663202']

for pathway in pathways:
    model = pybiopax.model_from_reactome(pathway)
    node_data, rel_data = extract_pathways(model, node_data, rel_data)
    node_data, rel_data = extract_reaction(model, node_data, rel_data)
    node_data, rel_data = extract_complexes(model, node_data, rel_data)
    node_data = extract_proteins(model, node_data)
    node_data = extract_small_molecules(model, node_data)
# Out:
# Processing OWL elements:   0%|          | 0.00/78.2k [00:00<?, ?it/s]
# Processing OWL elements:   0%|          | 0.00/33.3k [00:00<?, ?it/s]

# %%
nodes = pd.DataFrame(node_data)
nodes.tail(500)
# Out:
#               entity              id    reactome_id  \
# 15222        Protein  uniprot:P36888  R-HSA-9695714
# 15223        Protein  uniprot:P36888  R-HSA-9695721
# 15224        Protein  uniprot:P36888  R-HSA-9695722
# 15225        Protein  uniprot:P36888  R-HSA-9695718
# 15226        Protein  uniprot:P36888  R-HSA-9699435
# 15227        Protein  uniprot:P36888  R-HSA-9682301
# 15228        Protein  uniprot:P36888  R-HSA-9682313
# 15229        Protein  uniprot:P36888  R-HSA-9691906
# 15618  SmallMolecule                  R-ALL-1217507
# 15619  SmallMolecule                  R-ALL-1217505
# 15620  SmallMolecule                  R-ALL-1217510
# 15621  SmallMolecule                  R-ALL-1217514
# 15622  SmallMolecule                  R-ALL-1173285
# 15623  SmallMolecule                  R-ALL-1169429
# 15624  SmallMolecule                  R-ALL-1216521
# 15625  SmallMolecule                  R-ALL-1216528
# 15626  SmallMolecule                  R-ALL-1216524
# 15627  SmallMolecule                  R-ALL-1227674
# 15628  SmallMolecule                  R-ALL-1216527
# 15629  SmallMolecule                  R-ALL-1227677
# 15630  SmallMolecule                  R-ALL-1220577
# 15631  SmallMolecule                  R-ALL-1839035
# 15632  SmallMolecule                  R-ALL-2023389
# 15633  SmallMolecule                  R-ALL-2038886
# 15634  SmallMolecule                  R-ALL-2038919
# 15635  SmallMolecule                  R-ALL-2038925
# 15636  SmallMolecule                  R-ALL-2054052
# 15637  SmallMolecule                  R-ALL-2023385
# 15638  SmallMolecule                  R-ALL-2023387
# 15639  SmallMolecule                  R-ALL-2023377
# 15640  SmallMolecule     chebi:28815   R-ALL-190915
# 15641  SmallMolecule                  R-ALL-2038921
# 15642  SmallMolecule                  R-ALL-2023393
# 15643  SmallMolecule                  R-ALL-9616920
# 15644  SmallMolecule                  R-ALL-2077524
# 15645  SmallMolecule                  R-ALL-9616923
# 15646  SmallMolecule                  R-ALL-9652364
# 15647  SmallMolecule                  R-ALL-9649879
# 15648  SmallMolecule                  R-ALL-9649889
# 15649  SmallMolecule                  R-ALL-9649894
# 15650  SmallMolecule                  R-ALL-9646810
# 15651  SmallMolecule                  R-ALL-9649872
# 15652  SmallMolecule                  R-ALL-2399744
# 15653  SmallMolecule                  R-ALL-2399772
# 15654  SmallMolecule                  R-ALL-2399771
# 15655  SmallMolecule                  R-ALL-2399863
# 15656  SmallMolecule                  R-ALL-2399886
# 15657  SmallMolecule                  R-ALL-2399804
# 15658  SmallMolecule                  R-ALL-2399860
# 15659  SmallMolecule                  R-ALL-2399739
# 15660  SmallMolecule                  R-ALL-2399848
# 15661  SmallMolecule                  R-ALL-2399768
# 15662  SmallMolecule     chebi:50114  R-ALL-9027649
# 15663  SmallMolecule     chebi:30616    R-ALL-29358
# 15664  SmallMolecule    chebi:456216   R-ALL-113582
# 15665  SmallMolecule                  R-ALL-2399927
# 15666  SmallMolecule                  R-ALL-2404226
# 15667  SmallMolecule                  R-ALL-9616958
# 15668  SmallMolecule     chebi:15377    R-ALL-29356
# 15669  SmallMolecule     chebi:29105   R-ALL-109265
# 15670  SmallMolecule                  R-ALL-5262604
# 15671  SmallMolecule                  R-ALL-5340556
# 15672  SmallMolecule     chebi:16113   R-ALL-174672
# 15673  SmallMolecule     chebi:18367  R-ALL-1132287
# 15674  SmallMolecule     chebi:29108    R-ALL-74016
# 15675  SmallMolecule                   R-ALL-377604
# 15676  SmallMolecule     chebi:29108    R-ALL-74112
# 15677  SmallMolecule     chebi:29035   R-ALL-266099
# 15678  SmallMolecule     chebi:18420   R-ALL-114632
# 15679  SmallMolecule                  R-ALL-6802252
# 15680  SmallMolecule                  R-ALL-6802253
# 15681  SmallMolecule                  R-ALL-9657027
# 15682  SmallMolecule                  R-ALL-9657029
# 15683  SmallMolecule                  R-ALL-9657514
# 15684  SmallMolecule                  R-ALL-6802250
# 15685  SmallMolecule                  R-ALL-9657033
# 15686  SmallMolecule                  R-ALL-9657547
# 15687  SmallMolecule     chebi:43474    R-ALL-29372
# 15688  SmallMolecule                  R-ALL-9659761
# 15689  SmallMolecule                  R-ALL-9669720
# 15690  SmallMolecule                  R-ALL-9669716
# 15691  SmallMolecule                  R-ALL-9669717
# 15692  SmallMolecule                  R-ALL-9669723
# 15693  SmallMolecule                  R-ALL-9669718
# 15694  SmallMolecule                  R-ALL-9669719
# 15695  SmallMolecule                  R-ALL-9671491
# 15696  SmallMolecule                  R-ALL-9674322
# 15697  SmallMolecule                  R-ALL-9674072
# 15698  SmallMolecule     chebi:15378    R-ALL-70106
# 15699  SmallMolecule     chebi:57783    R-ALL-29364
# 15700  SmallMolecule     chebi:15379    R-ALL-29368
# 15701  SmallMolecule     chebi:16240    R-ALL-29408
# 15702  SmallMolecule     chebi:58349    R-ALL-29366
# 15703  SmallMolecule                  R-ALL-9674318
# 15704  SmallMolecule                  R-ALL-9677649
# 15705  SmallMolecule                  R-ALL-9695994
# 15706  SmallMolecule                  R-ALL-9695700
# 15707  SmallMolecule                  R-ALL-9695703
# 15708  SmallMolecule                  R-ALL-9699412
# 15709  SmallMolecule                  R-ALL-9699411
# 15710  SmallMolecule                  R-ALL-9702979
# 15711  SmallMolecule                  R-ALL-9702985
# 15712  SmallMolecule                  R-ALL-9702989
# 15713  SmallMolecule                  R-ALL-9699597
# 15714  SmallMolecule                  R-ALL-9699602
# 15715  SmallMolecule                  R-ALL-9699608
# 15716  SmallMolecule                  R-ALL-9699607
# 15717  SmallMolecule                  R-ALL-9699601
# 15718  SmallMolecule                  R-ALL-9702126
# 15719  SmallMolecule                  R-ALL-9702130
# 15720  SmallMolecule                  R-ALL-9702330
# 15721  SmallMolecule                  R-ALL-9702329
#
#                                       name  \
# 15222                                STK-1
# 15223                                STK-1
# 15224                                STK-1
# 15225                                STK-1
# 15226                           FLT3 Y842C
# 15227                                STK-1
# 15228                                STK-1
# 15229                                STK-1
# 15230                                STK-1
# 15231                                STK-1
# 15232                                STK-1
# 15233                                STK-1
# 15234                                STK-1
# 15235                                STK-1
# 15236                                STK-1
# 15237                                STK-1
# 15238                                STK-1
# 15239                                STK-1
# 15240                                STK-1
# 15241                           FLT3 Y842H
# 15242                                STK-1
# 15243                                STK-1
# 15244                                STK-1
# 15245                                STK-1
# 15246                                STK-1
# 15247                                STK-1
# 15248                                STK-1
# 15249                                  Mt5
# 15250                                  Mt6
# 15251                                  Mt1
# 15252                                  Mt3
# 15253                                  Mt2
# 15254                                  Mt4
# 15255                                  W78
# 15256                                   T6
# 15257                                  W51
# 15258                                 Npos
# 15259                                  W73
# 15260                              MOLM-14
# 15261                                 ITD2
# 15262                                 ITD3
# 15263                                 ITD4
# 15264                                 Mut2
# 15265                                 ITD4
# 15266                              MOLM-14
# 15267                               MV4-11
# 15268                                 ITD1
# 15269                                 ITD2
# 15270                                STK-1
# 15271                                STK-1
# 15272                                STK-1
# 15273                                STK-1
# 15274                                STK-1
# 15275                                STK-1
# 15276                                STK-1
# 15277                                STK-1
# 15278                                STK-1
# 15279                                STK-1
# 15280                                STK-1
# 15281                                STK-1
# 15282                                STK-1
# 15283                                STK-1
# 15284                                STK-1
# 15285                                STK-1
# 15286                                STK-1
# 15287                                STK-1
# 15288                                STK-1
# 15289                                STK-1
# 15290                                STK-1
# 15291                                STK-1
# 15292                      p-6Y FLT3 Y842C
# 15293                                STK-1
# 15294                                STK-1
# 15295                                STK-1
# 15296                                STK-1
# 15297                                STK-1
# 15298                                STK-1
# 15299                                STK-1
# 15300                                STK-1
# 15301                                STK-1
# 15302                                STK-1
# 15303                                STK-1
# 15304                                STK-1
# 15305                                STK-1
# 15306                                STK-1
# 15307                      p-6Y FLT3 Y842H
# 15308                                 GRB2
# 15309                                 SHP2
# 15310                                STAT5
# 15311                                 SHP2
# 15312                              p-STAT5
# 15313                               BCL2L1
# 15314                                  p21
# 15315                                 NOX4
# 15316                                 PIM1
# 15317                          CBL mutants
# 15318                            CBL R420Q
# 15319                            CBL R420G
# 15320                           del exon 8
# 15321                       CBL del366-477
# 15322                            CBL H398Y
# 15323                            CBL L380P
# 15324                            CBL P417A
# 15325                            CBL S376F
# 15326                            CBL L287R
# 15327                            CBL R499L
# 15328                            CBL Y371H
# 15329                            CBL R420*
# 15330                            CBL R420L
# 15331                            CBL R420P
# 15332                            CBL G375P
# 15333                            CBL G375S
# 15334                        CBL G375fs*16
# 15335                            CBL H398D
# 15336                            CBL H398N
# 15337                            CBL H398P
# 15338                            CBL H398Q
# 15339                            CBL H398R
# 15340                            CBL L380R
# 15341                            CBL P417H
# 15342                            CBL P417L
# 15343                            CBL P417R
# 15344                            CBL P417S
# 15345                            CBL R499*
# 15346                            CBL R499Q
# 15347                            CBL Y371C
# 15348                            CBL Y371D
# 15349                            CBL Y371S
# 15350                            CBL Y371N
# 15351                 FLT3 fusion proteins
# 15352                                  EF1
# 15353                           ETV6_HUMAN
# 15354                          GOGB1_HUMAN
# 15355                          SPTB2_HUMAN
# 15356                          TRIPB_HUMAN
# 15357                          ZMYM2_HUMAN
# 15358                          ZMYM2_HUMAN
# 15359                          MY18A_HUMAN
# 15360                           ETV6_HUMAN
# 15361                           ETV6_HUMAN
# 15362                                  EF1
# 15363                           ETV6_HUMAN
# 15364                           ETV6_HUMAN
# 15365                           ETV6_HUMAN
# 15366                          GOGB1_HUMAN
# 15367                          SPTB2_HUMAN
# 15368                          TRIPB_HUMAN
# 15369                          ZMYM2_HUMAN
# 15370                          ZMYM2_HUMAN
# 15371                          MY18A_HUMAN
# 15372                           ETV6_HUMAN
# 15373                                  EF1
# 15374  cabozantinib-sensitive FLT3 mutants
# 15375  pexidartinib-sensitive FLT3 mutants
# 15376     sorafenib-sensitive FLT3 mutants
# 15377                           FLT3 F621L
# 15378                           FLT3 N676D
# 15379     sunitinib-sensitive FLT3 mutants
# 15380    tandutinib-sensitive FLT3 mutants
# 15381   quizartinib-sensitive FLT3 mutants
# 15382     ponatinib-sensitive FLT3 mutants
# 15383                                STK-1
# 15384                                STK-1
# 15385                           FLT3 A848P
# 15386                           FLT3 A627P
# 15387  pexidartinib-resistant FLT3 mutants
# 15388   quizartinib-resistant FLT3 mutants
# 15389                           FLT3 F691I
# 15390     ponatinib-resistant FLT3 mutants
# 15391     sorafenib-resistant FLT3 mutants
# 15392     sunitinib-resistant FLT3 mutants
# 15393    tandutinib-resistant FLT3 mutants
# 15394                  ALK fusion proteins
# 15395                           PUR9_HUMAN
# 15396                           CLH1_HUMAN
# 15397                          DCTN1_HUMAN
# 15398                           variant 3a
# 15399                           variant 3b
# 15400                            variant 4
# 15401                            variant 1
# 15402                            variant 2
# 15403                           FINC_HUMAN
# 15404                           KINH_HUMAN
# 15405                           MOES_HUMAN
# 15406                                  B23
# 15407                             Striatin
# 15408                             TFGs-ALK
# 15409                                 TFGl
# 15410                                TFGxl
# 15411                           TPM3_HUMAN
# 15412                           TPM4_HUMAN
# 15413                           WDCP_HUMAN
# 15414                           CLH1_HUMAN
# 15415                           PUR9_HUMAN
# 15416                           EF1G_HUMAN
# 15417                           KLC1_HUMAN
# 15418                           HIP1_HUMAN
# 15419                              H21:A20
# 15420                              H28:A20
# 15421                            TPR_HUMAN
# 15422                          DCTN1_HUMAN
# 15423                          DCTN1_HUMAN
# 15424                          SQSTM_HUMAN
# 15425                          LIPB1_HUMAN
# 15426                          LIPB1_HUMAN
# 15427                           SYCC_HUMAN
# 15428                          SC31A_HUMAN
# 15429                             Vinculin
# 15430                          BIRC6_HUMAN
# 15431                          E2AK3_HUMAN
# 15432                          PPM1B_HUMAN
# 15433                           KAP0_HUMAN
# 15434                           GCC2_HUMAN
# 15435                           LMO7_HUMAN
# 15436                           RBP2_HUMAN
# 15437                          RRBP1_HUMAN
# 15438                          BC11A_HUMAN
# 15439                                  B23
# 15440                          EMAL4_HUMAN
# 15441                           variant 3a
# 15442                           variant 3b
# 15443                                  B23
# 15444                             TFGs-ALK
# 15445                                 TFGl
# 15446                                TFGxl
# 15447                           TPM3_HUMAN
# 15448                           TPM4_HUMAN
# 15449                           CLH1_HUMAN
# 15450                           PUR9_HUMAN
# 15451                           KINH_HUMAN
# 15452                             Striatin
# 15453                          DCTN1_HUMAN
# 15454                           MOES_HUMAN
# 15455                           FINC_HUMAN
# 15456                            variant 4
# 15457                            variant 2
# 15458                           WDCP_HUMAN
# 15459                           CLH1_HUMAN
# 15460                           PUR9_HUMAN
# 15461                           EF1G_HUMAN
# 15462                           KLC1_HUMAN
# 15463                           HIP1_HUMAN
# 15464                           HIP1_HUMAN
# 15465                           HIP1_HUMAN
# 15466                            TPR_HUMAN
# 15467                          DCTN1_HUMAN
# 15468                          DCTN1_HUMAN
# 15469                          SQSTM_HUMAN
# 15470                          LIPB1_HUMAN
# 15471                          LIPB1_HUMAN
# 15472                           SYCC_HUMAN
# 15473                          SC31A_HUMAN
# 15474                             Vinculin
# 15475                          BIRC6_HUMAN
# 15476                          E2AK3_HUMAN
# 15477                          PPM1B_HUMAN
# 15478                           KAP0_HUMAN
# 15479                           GCC2_HUMAN
# 15480                           LMO7_HUMAN
# 15481                           RBP2_HUMAN
# 15482                          RRBP1_HUMAN
# 15483                          BC11A_HUMAN
# 15484                                  B23
# 15485         MYH9- and RNF213-ALK fusions
# 15486                             Myosin-9
# 15487                          RN213_HUMAN
# 15488    p-7Y MYH9- and RNF213-ALK fusions
# 15489                             Myosin-9
# 15490                          RN213_HUMAN
# 15491            kinase domain ALK mutants
# 15492                            ALK_HUMAN
# 15493                            ALK_HUMAN
# 15494                            ALK_HUMAN
# 15495                            ALK_HUMAN
# 15496                            ALK_HUMAN
# 15497                            ALK_HUMAN
# 15498                            ALK_HUMAN
# 15499                            ALK_HUMAN
# 15500                            ALK_HUMAN
# 15501                            ALK_HUMAN
# 15502                            ALK_HUMAN
# 15503                            ALK_HUMAN
# 15504                            ALK_HUMAN
# 15505                            ALK_HUMAN
# 15506                            ALK_HUMAN
# 15507                            ALK_HUMAN
# 15508                            ALK_HUMAN
# 15509                            ALK_HUMAN
# 15510                            ALK_HUMAN
# 15511                            ALK_HUMAN
# 15512                            ALK_HUMAN
# 15513                            ALK_HUMAN
# 15514                            ALK_HUMAN
# 15515                            ALK_HUMAN
# 15516                            ALK_HUMAN
# 15517                            ALK_HUMAN
# 15518                            ALK_HUMAN
# 15519     juxtamembrane domain ALK mutants
# 15520                            ALK_HUMAN
# 15521                            ALK_HUMAN
# 15522                            ALK_HUMAN
# 15523     extracellular domain ALK mutants
# 15524                            ALK H694R
# 15525                            ALK_HUMAN
# 15526                            ALK_HUMAN
# 15527                            ALK G881D
# 15528                            ALK S413N
# 15529                            ALK V597A
# 15530                            ALK_HUMAN
# 15531                            ALK_HUMAN
# 15532                            ALK_HUMAN
# 15533                            ALK_HUMAN
# 15534                            ALK_HUMAN
# 15535                            ALK_HUMAN
# 15536                            ALK_HUMAN
# 15537                            ALK_HUMAN
# 15538                            ALK_HUMAN
# 15539                            ALK_HUMAN
# 15540                            ALK_HUMAN
# 15541                            ALK_HUMAN
# 15542                            ALK_HUMAN
# 15543                            ALK_HUMAN
# 15544                            ALK_HUMAN
# 15545                            ALK_HUMAN
# 15546                            ALK_HUMAN
# 15547                            ALK_HUMAN
# 15548                            ALK_HUMAN
# 15549                            ALK_HUMAN
# 15550                            ALK_HUMAN
# 15551                            ALK_HUMAN
# 15552                            ALK_HUMAN
# 15553                            ALK_HUMAN
# 15554                            ALK_HUMAN
# 15555                            ALK_HUMAN
# 15556                            ALK_HUMAN
# 15557                            ALK_HUMAN
# 15558                            ALK_HUMAN
# 15559                            ALK_HUMAN
# 15560                            ALK_HUMAN
# 15561                            ALK_HUMAN
# 15562                            ALK_HUMAN
# 15563                            ALK_HUMAN
# 15564                            ALK_HUMAN
# 15565                            ALK_HUMAN
# 15566                            ALK_HUMAN
# 15567                            ALK_HUMAN
# 15568                                STAT3
# 15569                         SHC1 p46,p52
# 15570                                 SHC1
# 15571                                 SHC1
# 15572             p-3Y SHC1-2, p-3Y SHC1-3
# 15573                                 SHC1
# 15574                                 SHC1
# 15575                                  ALK
# 15576                               FRS2,3
# 15577                                 FRS3
# 15578                         Phospho-FRS2
# 15579                            p-5Y-FRS3
# 15580                                 IRS1
# 15581                                IRS-1
# 15582                                MECP2
# 15583                               MECP2A
# 15584                               MECP2B
# 15585                               STAT5A
# 15586                                  B23
# 15587                                 NPM1
# 15588                               ZC3HC1
# 15589                           NIPA_HUMAN
# 15590                             p42-MAPK
# 15591                    p-T202,Y204-MAPK3
# 15592                          p-T,Y MAPKs
# 15593                                 JUNB
# 15594                            p-5S-RPS6
# 15595                               BCL2A1
# 15596                                  LAP
# 15597                                STAT3
# 15598                            ALK_HUMAN
# 15599                            ALK_HUMAN
# 15600                            ALK_HUMAN
# 15601                            ALK_HUMAN
# 15602                            ALK_HUMAN
# 15603                            ALK_HUMAN
# 15604                            ALK_HUMAN
# 15605                            ALK_HUMAN
# 15606                            ALK_HUMAN
# 15607                            ALK_HUMAN
# 15608                            ALK_HUMAN
# 15609                            ALK_HUMAN
# 15610                            ALK_HUMAN
# 15611                                  ATP
# 15612                                  ADP
# 15613                                  GDP
# 15614                                  GTP
# 15615                                 PIP2
# 15616                                 PIP3
# 15617                               17-AAG
# 15618                              17-DMAG
# 15619                         Geldanamycin
# 15620                           herbimycin
# 15621                              IPI-504
# 15622                              Tarceva
# 15623                               Iressa
# 15624                               Tykerb
# 15625                               ZD6474
# 15626                              EKB-569
# 15627                               WZ4002
# 15628                              HKI-272
# 15629                              CI-1033
# 15630                             Afatinib
# 15631                               TKI258
# 15632                                E3810
# 15633                              AZD4547
# 15634                             PD173074
# 15635                               BGJ398
# 15636                               SU5402
# 15637                             Brivanib
# 15638                           BMS 582664
# 15639                              AZ 2171
# 15640                                   HS
# 15641                               PKC412
# 15642                                E7080
# 15643                             GW 78603
# 15644                               AB1010
# 15645                             BIBF1120
# 15646                               AEE788
# 15647                               AZ5104
# 15648                            CP-724714
# 15649                            Sapitinib
# 15650                                XL647
# 15651                          Osimertinib
# 15652                               BEZ235
# 15653                               BGT226
# 15654                               BKM120
# 15655                                XL765
# 15656                                XL147
# 15657                              GDC0941
# 15658                               PX-866
# 15659                             LY294002
# 15660                           wortmannin
# 15661                           GSK1059615
# 15662                                 ESTG
# 15663                                  ATP
# 15664                                  ADP
# ...
# 15720                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ASP3026|ASP-3026|ASP 3026
# 15721                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          AZD3463|AZD-3463|CS-1382|HY-15609|KB-154896
#
#       version
# 15222      79
# 15223      79
# 15224      79
# 15225      79
# 15226      79
# 15227      79
# 15228      79
# 15229      79
# 15230      79
# 15231      79
# 15232      79
# 15233      79
# 15234      79
# 15235      79
# 15236      79
# 15237      79
# 15238      79
# 15239      79
# 15240      79
# 15241      79
# 15242      79
# 15243      79
# 15244      79
# 15245      79
# 15246      79
# 15247      79
# 15248      79
# 15249      79
# 15250      79
# 15251      79
# 15252      79
# 15253      79
# 15254      79
# 15255      79
# 15256      79
# 15257      79
# 15258      79
# 15259      79
# 15260      79
# 15261      79
# 15262      79
# 15263      79
# 15264      79
# 15265      79
# 15266      79
# 15267      79
# 15268      79
# 15269      79
# 15270      79
# 15271      79
# 15272      79
# 15273      79
# 15274      79
relationships = pd.DataFrame(rel_data)
relationships.fillna('', inplace=True)
relationships.tail(5)
# Out:
#         entity              id    reactome_id parent_entity  \
# 18412  Protein  uniprot:Q9UM73  R-HSA-9701428       Complex
# 18413  Protein  uniprot:Q9UM73  R-HSA-9701838       Complex
# 18414  Protein  uniprot:Q9UM73  R-HSA-9701418       Complex
# 18415  Protein  uniprot:Q9UM73  R-HSA-9699831       Complex
# 18416  Protein  uniprot:Q9UM73  R-HSA-9699802       Complex
#
#                     parent_id version relationship
# 18412  reactome:R-HSA-9701834      79      PART_OF
# 18413  reactome:R-HSA-9701827      79      PART_OF
# 18414  reactome:R-HSA-9701837      79      PART_OF
# 18415  reactome:R-HSA-9700557      79      PART_OF
# 18416  reactome:R-HSA-9700595      79      PART_OF

# %%
def create_nodes(df, entity):
    # create node dataframe
    df_entity = df[(df['entity'] == entity)]
    df_nodes = df_entity[['id', 'name', 'synonyms']].copy()
    df_nodes.drop_duplicates(subset='id', inplace=True)
    df_nodes = df_nodes[(df_nodes['id'] != '')]
    
    return df_nodes

# %%
def create_relationships(df, entity, relationship, parent_entity):
    # create node dataframe
    df_entity = df[(df['entity'] == entity) & (df['parent_entity'] == parent_entity) &
                   (df['relationship'] == relationship)]
    
    # create relationship dataframe
    df_relationships = df_entity[['id', 'parent_id']].copy()
    df_relationships.rename(columns={'id': 'from', 'parent_id': 'to'}, inplace=True)
    df_relationships.drop_duplicates(subset=['from', 'to'], inplace=True)
    df_relationships = df_relationships[(df_relationships['from'] != '') & (df_relationships['to'] != '')]
    
    return df_relationships

# %% [markdown]
# ## Setup Output Directories

# %%
NODE_DATA = os.getenv('NODE_DATA', default='../data/nodes/')
RELATIONSHIP_DATA = os.getenv('RELATIONSHIP_DATA', default='../data/relationships/')

# %%
os.makedirs(os.path.join(NODE_DATA), exist_ok=True)
os.makedirs(os.path.join(RELATIONSHIP_DATA), exist_ok=True)

# %%
def save_nodes(key, df):
    nodes = create_nodes(df, key)
    nodes.to_csv(os.path.join(NODE_DATA, f'{key}.csv'), index=False)
    print(key, nodes.shape[0])

# %%
def save_relationships(key, df):
    relationships = create_relationships(df, key[0], key[1], key[2])
    relationships.to_csv(os.path.join(RELATIONSHIP_DATA, f'{key[0]}-{key[1]}-{key[2]}.csv'), index=False)
    print(f'{key[0]}-{key[1]}-{key[2]}', relationships.shape[0])

# %%
node_groups = nodes.groupby('entity')

print('Saving:')
for key, group in node_groups:
    save_nodes(key, group)
# Out:
# Saving:
# Complex 4340
# Pathway 574
# Protein 2554
# Reaction 2931
# SmallMolecule 246

# %%
relationship_groups = relationships.groupby(['entity','relationship', 'parent_entity'])

print('Saving:')
for key, group in relationship_groups:
        save_relationships(key, group)
# Out:
# Saving:
# BiochemicalReaction-PART_OF-Pathway 3028
# Complex-PARTICIPATES_IN-BiochemicalReaction 4583
# Complex-PART_OF-Complex 2327
# Pathway-IS_A-Pathway 578
# Protein-PARTICIPATES_IN-BiochemicalReaction 1434
# Protein-PART_OF-Complex 3549
# SmallMolecule-PARTICIPATES_IN-BiochemicalReaction 1897
# SmallMolecule-PART_OF-Complex 398
